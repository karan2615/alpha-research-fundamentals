# %% [markdown]
# # Alpha Research — Homework 2
# **Luca Ragazzi & Jaskaran Kalra**
#
# ### Objective
# Construction of a point-in-time S&P 500 universe, collection of market and alternative data, data quality analysis, cross-referencing, and a first OLS modelling attempt.
#
# ### Sample Period
# January 2010 — May 2026
#
# ### Universe
# S&P 500 constituents as of January 1, 2010, sourced from the fja05680/sp500 GitHub repository — a point-in-time source tracking all historical additions and removals since 1996.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import os
import urllib.request
import json
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy import stats

# ── Create data directory ─────────────────────────────────────────────
os.makedirs('data', exist_ok=True)

# %%
import time

# %%
# ── Load historical S&P 500 constituents ─────────────────────────────
pit = pd.read_csv('../data/sp500/S&P 500 Historical Components & Changes(01-17-2026).csv')
pit['date'] = pd.to_datetime(pit['date'])

# ── Extract PIT snapshot at 2010-01-01 ───────────────────────────────
pit_date = pd.Timestamp('2010-01-01')
snapshot = pit[pit['date'] <= pit_date].iloc[-1]

print(f"Snapshot date: {snapshot['date'].date()}")

# ── Parse tickers ─────────────────────────────────────────────────────
tickers = [t.strip() for t in snapshot['tickers'].split(',')]

print(f"Constituents at {pit_date.date()}: {len(tickers)}")
print(f"First 10 tickers: {tickers[:10]}")
# Out:
# Snapshot date: 2009-12-30
# Constituents at 2010-01-01: 499
# First 10 tickers: ['A', 'AABA', 'AAPL', 'ABC', 'ABT', 'ACS', 'ADBE', 'ADI', 'ADM', 'ADP']

# %%
# ── Download prices from yfinance ────────────────────────────────────
prices = yf.download(
    tickers,
    start='2010-01-01',
    end='2026-05-16',
    auto_adjust=True
)['Close']

print(f"Downloaded prices shape: {prices.shape}")
print(f"Date range: {prices.index[0].date()} to {prices.index[-1].date()}")
# Out:
# [**********************50%                       ]  251 of 499 completed$STJ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************51%                       ]  252 of 499 completed$LM: possibly delisted; no timezone found
# $RAI: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************52%                       ]  260 of 499 completed$IGT: possibly delisted; no timezone found
# [**********************52%                       ]  261 of 499 completed$HRS: possibly delisted; no timezone found
# [**********************53%                       ]  262 of 499 completed$BJS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************55%*                      ]  274 of 499 completed$GPS: possibly delisted; no timezone found
# [**********************56%**                     ]  281 of 499 completed$MYL: possibly delisted; no timezone found
# [**********************58%***                    ]  289 of 499 completed$CHK: possibly delisted; no timezone found
# [**********************58%***                    ]  290 of 499 completed$FRX: possibly delisted; no timezone found
# [**********************58%***                    ]  291 of 499 completed$NYX: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************60%****                   ]  300 of 499 completed$WYND: possibly delisted; no timezone found
# [**********************61%****                   ]  305 of 499 completed$WBA: possibly delisted; no timezone found
# [**********************61%****                   ]  306 of 499 completed$DFS: possibly delisted; no timezone found
# [**********************64%******                 ]  321 of 499 completed$MON: possibly delisted; no timezone found
# [**********************65%******                 ]  322 of 499 completed$DO: possibly delisted; no timezone found
# [**********************65%******                 ]  325 of 499 completed$PCP: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************67%*******                ]  334 of 499 completed$ACS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************69%********               ]  345 of 499 completed$MMC: possibly delisted; no timezone found
# [**********************69%********               ]  346 of 499 completed$EKDKQ: possibly delisted; no timezone found
# [**********************72%**********             ]  358 of 499 completed$AGN: possibly delisted; no timezone found
# [**********************73%**********             ]  363 of 499 completed$ATGE: possibly delisted; no timezone found
# $DF: possibly delisted; no timezone found
# [**********************73%**********             ]  364 of 499 completed$WIN: possibly delisted; no timezone found
# [**********************73%**********             ]  366 of 499 completed$MIL: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************75%***********            ]  374 of 499 completed$RSHCQ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************75%***********            ]  375 of 499 completed$CFN: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************77%************           ]  382 of 499 completed$DTV: possibly delisted; no timezone found
# [**********************77%************           ]  383 of 499 completed$BCR: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# $BDK: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************77%************           ]  384 of 499 completed$AKS: possibly delisted; no timezone found
# [**********************79%*************          ]  396 of 499 completed$UTX: possibly delisted; no timezone found
# [**********************80%*************          ]  397 of 499 completed$ODP: possibly delisted; no timezone found
# $TIF: possibly delisted; no timezone found
# [**********************80%*************          ]  398 of 499 completed$JNPR: possibly delisted; no timezone found
# [**********************81%**************         ]  406 of 499 completed$VAR: possibly delisted; no timezone found
# [**********************82%**************         ]  407 of 499 completed$PKI: possibly delisted; no timezone found
# [**********************82%**************         ]  410 of 499 completed$XTO: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************85%****************       ]  425 of 499 completed$SWY: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************86%****************       ]  427 of 499 completed$JNS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************86%****************       ]  428 of 499 completed$PDCO: possibly delisted; no timezone found
# [**********************86%****************       ]  429 of 499 completed$SNI: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************88%*****************      ]  441 of 499 completed$CMA: possibly delisted; no timezone found
# [**********************89%******************     ]  443 of 499 completed$LLTC: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************91%*******************    ]  452 of 499 completed$FTR: possibly delisted; no timezone found
# [**********************92%*******************    ]  457 of 499 completed$SWN: possibly delisted; no timezone found
# [**********************92%*******************    ]  458 of 499 completed$TSS: possibly delisted; no timezone found
# [**********************94%********************   ]  467 of 499 completed$SRCL: possibly delisted; no timezone found
# [**********************95%*********************  ]  472 of 499 completed$LSI: possibly delisted; no timezone found
# [**********************95%*********************  ]  474 of 499 completed$HCBK: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# $ABC: possibly delisted; no timezone found
# [**********************97%********************** ]  482 of 499 completed$BIG: possibly delisted; no timezone found
# [**********************97%********************** ]  483 of 499 completed$PBCT: possibly delisted; no timezone found
# [**********************97%********************** ]  484 of 499 completed$BF.B: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************98%********************** ]  491 of 499 completed$JEC: possibly delisted; no timezone found
# [**********************99%***********************]  492 of 499 completed$HSP: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************99%***********************]  493 of 499 completed$JWN: possibly delisted; no timezone found
# [**********************99%***********************]  493 of 499 completed$HNZ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [*********************100%***********************]  498 of 499 completed$LO: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# $FII: possibly delisted; no timezone found
# [                       0%                       ]$NBL: possibly delisted; no timezone found
# [                       1%                       ]  3 of 499 completed$COG: possibly delisted; no timezone found
# [*                      2%                       ]  10 of 499 completed$TWC: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [*                      2%                       ]  11 of 499 completed$MWW: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# $AABA: possibly delisted; no timezone found
# [**                     4%                       ]  18 of 499 completed$MRO: possibly delisted; no timezone found
# $RTN: possibly delisted; no timezone found
# [**                     4%                       ]  19 of 499 completed$RDC: possibly delisted; no timezone found
# [**                     4%                       ]  20 of 499 completed$RRD: possibly delisted; no timezone found
# $GAS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**                     4%                       ]  22 of 499 completed$ARNC: possibly delisted; no timezone found
# [**                     5%                       ]  23 of 499 completed$XLNX: possibly delisted; no timezone found
# [**                     5%                       ]  25 of 499 completed$BNI: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [***                    7%                       ]  33 of 499 completed$PLL: possibly delisted; no timezone found
# [***                    7%                       ]  34 of 499 completed$WFM: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [***                    7%                       ]  35 of 499 completed$CEPH: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [****                   8%                       ]  40 of 499 completed$ANTM: possibly delisted; no timezone found
# [****                   8%                       ]  41 of 499 completed$PX: possibly delisted; no timezone found
# [****                   8%                       ]  42 of 499 completed$RHT: possibly delisted; no timezone found
# [*****                 11%                       ]  57 of 499 completed$NOVL: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [******                12%                       ]  58 of 499 completed$NVLS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [******                12%                       ]  61 of 499 completed$AVP: possibly delisted; no timezone found
# [******                12%                       ]  62 of 499 completed$ETFC: possibly delisted; no timezone found
# [*******               15%                       ]  73 of 499 completed$VIAB: possibly delisted; no timezone found
# [*******               15%                       ]  74 of 499 completed$SUNEQ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [*******               15%                       ]  75 of 499 completed$LLL: possibly delisted; no timezone found
# [*******               15%                       ]  76 of 499 completed$MJN: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [*********             18%                       ]  90 of 499 completed$ALTR: possibly delisted; no timezone found
# [*********             18%                       ]  91 of 499 completed$X: possibly delisted; no timezone found
# [***********           22%                       ]  108 of 499 completed$PGN: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [***********           23%                       ]  116 of 499 completed$STR: possibly delisted; no timezone found
# [************          25%                       ]  124 of 499 completed$CVH: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [************          25%                       ]  125 of 499 completed$LXK: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [************          25%                       ]  126 of 499 completed$IPG: possibly delisted; no timezone found
# [************          26%                       ]  131 of 499 completed$HCP: possibly delisted; no timezone found
# [************          26%                       ]  132 of 499 completed$BTUUQ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**************        29%                       ]  143 of 499 completed$SYMC: possibly delisted; no timezone found
# [**************        30%                       ]  148 of 499 completed$MFE: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**************        30%                       ]  149 of 499 completed$MWV: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [***************       31%                       ]  155 of 499 completed$PXD: possibly delisted; no timezone found
# [***************       32%                       ]  158 of 499 completed$QLGC: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# $HSH: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [****************      33%                       ]  163 of 499 completed$CBS: possibly delisted; no timezone found
# [****************      34%                       ]  168 of 499 completed$BHGE: possibly delisted; no timezone found
# [*****************     36%                       ]  178 of 499 completed$JCP: possibly delisted; no timezone found
# [******************    37%                       ]  185 of 499 completed$TGNA: possibly delisted; no timezone found
# $APOL: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [******************    37%                       ]  186 of 499 completed$BRCM: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [******************    37%                       ]  187 of 499 completed$DNB: possibly delisted; no timezone found
# [******************    38%                       ]  189 of 499 completed$K: possibly delisted; no timezone found
# $TMK: possibly delisted; no timezone found
# [*******************   39%                       ]  194 of 499 completed$XL: possibly delisted; no timezone found
# $CTL: possibly delisted; no timezone found
# [*******************   39%                       ]  195 of 499 completed$DNR: possibly delisted; no timezone found
# [********************  41%                       ]  205 of 499 completed$BLL: possibly delisted; no timezone found
# [********************  41%                       ]  206 of 499 completed$FLIR: possibly delisted; no timezone found
# [********************* 43%                       ]  213 of 499 completed$CELG: possibly delisted; no timezone found
# [********************* 43%                       ]  214 of 499 completed$SIAL: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [********************* 43%                       ]  215 of 499 completed$MDP: possibly delisted; no timezone found
# [********************* 44%                       ]  218 of 499 completed$ARG: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************45%                       ]  223 of 499 completed$FDO: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************47%                       ]  236 of 499 completed$HES: possibly delisted; no timezone found
# [**********************47%                       ]  237 of 499 completed$CTXS: possibly delisted; no timezone found
# [**********************48%                       ]  238 of 499 completed$AYE: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************50%                       ]  249 of 499 completed$LM: possibly delisted; no timezone found
# [**********************51%                       ]  252 of 499 completed$RAI: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************51%                       ]  254 of 499 completed$STJ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************52%                       ]  259 of 499 completed$BJS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************52%                       ]  260 of 499 completed$HRS: possibly delisted; no timezone found
# $IGT: possibly delisted; no timezone found
# [**********************55%*                      ]  272 of 499 completed$GPS: possibly delisted; no timezone found
# [**********************56%**                     ]  279 of 499 completed$MYL: possibly delisted; no timezone found
# [**********************57%**                     ]  286 of 499 completed$FRX: possibly delisted; no timezone found
# [**********************58%***                    ]  291 of 499 completed$NYX: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************60%****                   ]  297 of 499 completed$WYND: possibly delisted; no timezone found
# [**********************60%****                   ]  298 of 499 completed$CHK: possibly delisted; no timezone found
# [**********************60%****                   ]  301 of 499 completed$DFS: possibly delisted; no timezone found
# [**********************63%*****                  ]  313 of 499 completed$WBA: possibly delisted; no timezone found
# [**********************63%*****                  ]  316 of 499 completed$MON: possibly delisted; no timezone found
# [**********************66%*******                ]  331 of 499 completed$DO: possibly delisted; no timezone found
# [**********************67%*******                ]  333 of 499 completed$PCP: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************67%*******                ]  335 of 499 completed$ACS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************69%********               ]  346 of 499 completed$EKDKQ: possibly delisted; no timezone found
# [**********************70%*********              ]  347 of 499 completed$MMC: possibly delisted; no timezone found
# [**********************72%**********             ]  358 of 499 completed$AGN: possibly delisted; no timezone found
# [**********************73%**********             ]  363 of 499 completed$ATGE: possibly delisted; no timezone found
# [**********************73%**********             ]  364 of 499 completed$DF: possibly delisted; no timezone found
# [**********************73%**********             ]  365 of 499 completed$MIL: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************73%**********             ]  366 of 499 completed$WIN: possibly delisted; no timezone found
# [**********************75%***********            ]  374 of 499 completed$RSHCQ: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************75%***********            ]  375 of 499 completed$CFN: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************77%************           ]  385 of 499 completed$DTV: possibly delisted; no timezone found
# $BCR: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************77%************           ]  386 of 499 completed$BDK: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************78%************           ]  387 of 499 completed$AKS: possibly delisted; no timezone found
# [**********************79%*************          ]  395 of 499 completed$UTX: possibly delisted; no timezone found
# [**********************79%*************          ]  396 of 499 completed$TIF: possibly delisted; no timezone found
# [**********************80%*************          ]  397 of 499 completed$JNPR: possibly delisted; no timezone found
# [**********************80%*************          ]  399 of 499 completed$XTO: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************81%**************         ]  405 of 499 completed$VAR: possibly delisted; no timezone found
# [**********************81%**************         ]  406 of 499 completed$ODP: possibly delisted; no timezone found
# [**********************82%**************         ]  411 of 499 completed$PKI: possibly delisted; no timezone found
# [**********************85%****************       ]  422 of 499 completed$SWY: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************86%****************       ]  427 of 499 completed$PDCO: possibly delisted; no timezone found
# [**********************86%****************       ]  428 of 499 completed$JNS: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************86%****************       ]  431 of 499 completed$SNI: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************88%*****************      ]  441 of 499 completed$CMA: possibly delisted; no timezone found
# [**********************89%******************     ]  442 of 499 completed$LLTC: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************90%******************     ]  451 of 499 completed$FTR: possibly delisted; no timezone found
# [**********************92%*******************    ]  458 of 499 completed$SWN: possibly delisted; no timezone found
# [**********************92%*******************    ]  459 of 499 completed$TSS: possibly delisted; no timezone found
# [**********************93%********************   ]  465 of 499 completed$SRCL: possibly delisted; no timezone found
# [**********************94%********************   ]  467 of 499 completed$HCBK: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************95%*********************  ]  474 of 499 completed$LSI: possibly delisted; no timezone found
# [**********************95%*********************  ]  476 of 499 completed$ABC: possibly delisted; no timezone found
# [**********************96%*********************  ]  478 of 499 completed$BF.B: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************97%********************** ]  482 of 499 completed$PBCT: possibly delisted; no timezone found
# [**********************97%********************** ]  483 of 499 completed$BIG: possibly delisted; no timezone found
# [**********************98%********************** ]  490 of 499 completed$JEC: possibly delisted; no timezone found
# [**********************99%***********************]  492 of 499 completed$HSP: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************99%***********************]  493 of 499 completed$JWN: possibly delisted; no timezone found
# [*********************100%***********************]  499 of 499 completed
#
# 124 Failed downloads:
# ['HNZ', 'LO', 'TWC', 'MWW', 'GAS', 'BNI', 'WFM', 'CEPH', 'NOVL', 'NVLS', 'SUNEQ', 'MJN', 'PGN', 'CVH', 'LXK', 'BTUUQ', 'MFE', 'MWV', 'QLGC', 'HSH', 'APOL', 'BRCM', 'SIAL', 'ARG', 'FDO', 'AYE', 'RAI', 'STJ', 'BJS', 'NYX', 'PCP', 'ACS', 'MIL', 'RSHCQ', 'CFN', 'BCR', 'BDK', 'XTO', 'SWY', 'JNS', 'SNI', 'LLTC', 'HCBK', 'BF.B', 'HSP']: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# ['FII', 'NBL', 'COG', 'AABA', 'MRO', 'RTN', 'RDC', 'RRD', 'ARNC', 'XLNX', 'PLL', 'ANTM', 'PX', 'RHT', 'AVP', 'ETFC', 'VIAB', 'LLL', 'ALTR', 'X', 'STR', 'IPG', 'HCP', 'SYMC', 'PXD', 'CBS', 'BHGE', 'JCP', 'TGNA', 'DNB', 'K', 'TMK', 'XL', 'CTL', 'DNR', 'BLL', 'FLIR', 'CELG', 'MDP', 'HES', 'CTXS', 'LM', 'HRS', 'IGT', 'GPS', 'MYL', 'FRX', 'WYND', 'CHK', 'DFS', 'WBA', 'MON', 'DO', 'EKDKQ', 'MMC', 'AGN', 'ATGE', 'DF', 'WIN', 'DTV', 'AKS', 'UTX', 'TIF', 'JNPR', 'VAR', 'ODP', 'PKI', 'PDCO', 'CMA', 'FTR', 'SWN', 'TSS', 'SRCL', 'LSI', 'ABC', 'PBCT', 'BIG', 'JEC', 'JWN']: possibly delisted; no timezone found
# Downloaded prices shape: (4117, 499)
# Date range: 2010-01-04 to 2026-05-15

# %% [markdown]
# ## Survivorship Bias Assessment
#
# Despite using a true point-in-time constituent list, 130 tickers
# (26% of the universe) could not be downloaded from yfinance due to
# delisting or data unavailability. This reintroduces survivorship bias
# comparable to using a current constituent list. Eliminating this bias
# entirely would require a commercial database such as CRSP or Compustat.

# %%
# ── Document and handle failed downloads ─────────────────────────────
failed_tickers = [
    'AABA', 'ABC', 'ACS', 'AGN', 'AKS', 'ALTR', 'ANTM', 'APOL', 'ARG', 'ARNC',
    'ATGE', 'AVP', 'AYE', 'BCR', 'BDK', 'BF.B', 'BHGE', 'BIG', 'BJS', 'BLL',
    'BNI', 'BRCM', 'BTUUQ', 'CBS', 'CELG', 'CEPH', 'CFN', 'CHK', 'CMA', 'COG',
    'CTL', 'CTXS', 'CVH', 'DF', 'DFS', 'DNB', 'DNR', 'DO', 'DTV', 'EKDKQ',
    'ETFC', 'FDO', 'FII', 'FLIR', 'FRX', 'FTR', 'GAS', 'GPS', 'HCBK', 'HCP',
    'HES', 'HNZ', 'HRS', 'HSH', 'HSP', 'IGT', 'IPG', 'JCP', 'JEC', 'JNPR',
    'JNS', 'JWN', 'K', 'LLL', 'LLTC', 'LM', 'LO', 'LSI', 'LXK', 'MDP',
    'MFE', 'MIL', 'MJN', 'MMC', 'MON', 'MRO', 'MWV', 'MWW', 'MYL', 'NBL',
    'NOVL', 'NVLS', 'NYX', 'ODP', 'PBCT', 'PCP', 'PDCO', 'PGN', 'PKI', 'PLL',
    'PX', 'PXD', 'QLGC', 'RAI', 'RDC', 'RHT', 'RRD', 'RSHCQ', 'RTN', 'SIAL',
    'SNI', 'SRCL', 'STJ', 'STR', 'SUNEQ', 'SVU', 'SWN', 'SWY', 'SYMC', 'TGNA',
    'TIF', 'TMK', 'TSS', 'TWC', 'UTX', 'VAR', 'VIAB', 'WBA', 'WFM', 'WIN',
    'WYND', 'X', 'XL', 'XLNX', 'XTO',
]

# Note: 125 tickers failed to download. These are companies that were
# delisted, acquired, or merged during the 2010-2026 period.
# For companies with partial data, yfinance returns prices up to their
# last trading day — those observations remain in the dataset.
# Only companies with zero data are excluded here.

successful_tickers = [t for t in tickers if t not in failed_tickers]
prices = prices[successful_tickers]

print(f"Successful downloads : {len(successful_tickers)}")
print(f"Failed downloads     : {len(failed_tickers)}")
print(f"Final prices shape   : {prices.shape}")

# ── Save raw prices ───────────────────────────────────────────────────
prices.to_csv('data/sp500_prices_raw.csv')
print("Prices saved to data/sp500_prices_raw.csv")

# %% [markdown]
# ## 3. Data Quality Analysis — Prices

# %%
# ── Data Quality Analysis — Prices ───────────────────────────────────
print(f"Shape: {prices.shape}")
print(f"Date range: {prices.index[0].date()} to {prices.index[-1].date()}")
print(f"Tickers: {len(prices.columns)}")

# Missing values per ticker
missing_pct = prices.isnull().sum() / len(prices) * 100
print(f"\nMissing values per ticker (%):")
print(missing_pct.describe())

# Tickers with more than 20% missing
high_missing = missing_pct[missing_pct > 20]
print(f"\nTickers with >20% missing values: {len(high_missing)}")
print(high_missing.sort_values(ascending=False).head(10))

# %% [markdown]
# ### Missing Values Treatment
#
# Tickers with more than 50% missing values are removed — these companies
# were delisted too early in the sample period to provide meaningful data.
# Tickers with partial data (delisted mid-sample) are retained as their
# valid observations contribute to reducing survivorship bias.

# %%
# ── Remove tickers with excessive missing values ───────────────────────
# Threshold: remove tickers with more than 50% missing values
# Tickers with <50% missing have sufficient data for meaningful analysis
threshold = 50
missing_pct = prices.isnull().sum() / len(prices) * 100

tickers_to_keep = missing_pct[missing_pct <= threshold].index.tolist()
prices_clean = prices[tickers_to_keep]

print(f"Prices shape before: {prices.shape}")
print(f"Prices shape after:  {prices_clean.shape}")
print(f"Tickers removed (>{threshold}% missing): {prices.shape[1] - prices_clean.shape[1]}")

# Save
prices_clean.to_csv('data/sp500_prices_clean.csv')
print(f"\nClean prices saved — {prices_clean.shape[1]} tickers retained")

# %% [markdown]
# ## 4. Predictor Datasets
#
# Four datasets are downloaded as potential predictors of future returns:
# 1. **VIX** — market fear index (sentiment)
# 2. **Fama-French Factors** — Mkt-RF, SMB, HML (asset pricing)
# 3. **FRED** — Fed Funds Rate, CPI, Unemployment Rate (macroeconomic)
# 4. **Momentum** — 12-month return excluding last month (technical)

# %%
# ── 1. VIX ───────────────────────────────────────────────────────────
vix = yf.download('^VIX', start='2010-01-01', end='2026-05-16', auto_adjust=True)['Close']
vix.to_csv('data/vix.csv')
print(f"VIX shape: {vix.shape}")

# ── 2. Fama-French ───────────────────────────────────────────────────
ff_url = 'https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip'
ff = pd.read_csv(ff_url, skiprows=3, index_col=0)
ff = ff[ff.index.astype(str).str.match(r'^\d{8}$')]
ff.index = pd.to_datetime(ff.index, format='%Y%m%d')
ff = ff.loc['2010-01-01':'2026-05-16']
ff.to_csv('data/famafrench.csv')
print(f"Fama-French shape: {ff.shape}")

# ── 3. FRED ──────────────────────────────────────────────────────────
FRED_API_KEY = 'fab4104d00c3061dee2126deb258f448'

def get_fred(series_id):
    url = f'https://api.stlouisfed.org/fred/series/observations?series_id={series_id}&api_key={FRED_API_KEY}&file_type=json'
    with urllib.request.urlopen(url) as response:
        data = json.loads(response.read())
    df = pd.DataFrame(data['observations'])[['date', 'value']]
    df.columns = ['date', series_id]
    df['date'] = pd.to_datetime(df['date'])
    df = df.set_index('date')
    df[series_id] = pd.to_numeric(df[series_id], errors='coerce')
    return df

# Download from 2009 to have 12 months history for CPI YoY calculation
fed_funds    = get_fred('FEDFUNDS')
cpi          = get_fred('CPIAUCSL')
time.sleep(1)
unemployment = get_fred('UNRATE')
fred = fed_funds.join(cpi).join(unemployment)
fred = fred.loc['2009-01-01':'2026-05-16']
fred.to_csv('data/fred.csv')
print(f"FRED shape: {fred.shape}")

# ── 4. Momentum ───────────────────────────────────────────────────────
# 12-month return excluding last month (Jegadeesh & Titman 1993)
momentum = np.log(prices_clean).diff(252).shift(21)
momentum.to_csv('data/momentum.csv')
print(f"Momentum shape: {momentum.shape}")

print(f"\nAll datasets saved to data")

# %% [markdown]
# ## 5. Data Quality Analysis — Predictor Datasets

# %%
# ── Data Quality — Predictor Datasets ────────────────────────────────
datasets = {'VIX': vix, 'Fama-French': ff, 'FRED': fred}

for name, df in datasets.items():
    print(f"{'='*50}")
    print(f"{name}")
    print(f"{'='*50}")
    print(f"Shape:          {df.shape}")
    print(f"Date range:     {df.index[0].date()} to {df.index[-1].date()}")
    print(f"Missing values: {df.isnull().sum().sum()}")
    print(f"Descriptive statistics:")
    print(df.describe())
    print()

# %%
# ── Check FRED missing values ─────────────────────────────────────────
print("FRED missing values:")
print(fred[fred.isnull().any(axis=1)])

# %%
# ── Forward fill FRED missing values ─────────────────────────────────
# October 2025: CPI and Unemployment not yet published at download time
# Forward fill with September 2025 values — conservative assumption
fred = fred.ffill()
print(f"Missing values after ffill: {fred.isnull().sum().sum()}")

# %% [markdown]
# ### FRED Missing Values
#
# One observation (2025-10-01) contained missing values for CPI and Unemployment Rate,
# likely due to publication lag at the time of download. Forward-filled with the
# most recent available values — a conservative and point-in-time consistent approach.

# %%
# ── Outlier Analysis — Daily Returns ─────────────────────────────────
returns = prices_clean.pct_change().dropna()

print("Daily Returns — Descriptive Statistics:")
print(returns.stack().describe())

print(f"\nExtreme returns (> 50% or < -50% in a single day):")
extreme_mask = (returns > 0.5) | (returns < -0.5)

for ticker in returns.columns:
    ticker_extreme = returns[ticker][extreme_mask[ticker]].dropna()
    if len(ticker_extreme) > 0:
        for date, value in ticker_extreme.items():
            print(f"  {ticker:6s} | {date.date()} | {value*100:+.1f}%")

# %%
# ── Remove corrupted tickers ──────────────────────────────────────────
# EP (El Paso Corporation, acquired 2012) and CPWR show corrupted price data
# likely due to ticker reassignment after delisting
corrupted = ['EP', 'CPWR']
prices_clean = prices_clean.drop(columns=corrupted, errors='ignore')
print(f"Removed corrupted tickers: {corrupted}")
print(f"Final prices shape: {prices_clean.shape}")

prices_clean.to_csv('data/sp500_prices_clean.csv')
print("Updated clean prices saved")
# Out:
# $MDP: possibly delisted; no timezone found
# [********************* 44%                       ]  219 of 499 completed$ARG: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [********************* 44%                       ]  222 of 499 completed$FDO: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************47%                       ]  235 of 499 completed$HES: possibly delisted; no timezone found
# [**********************47%                       ]  236 of 499 completed$CTXS: possibly delisted; no timezone found
# [**********************48%                       ]  242 of 499 completed$AYE: possibly delisted; no price data found  (1d 2010-01-01 -> 2026-05-16)
# [**********************50%                       ]  249 of 499 completed

# %% [markdown]
# ### Outlier Assessment
#
# Two tickers (EP, CPWR) exhibit clearly corrupted price data with no plausible economic explanation:
#
# - **EP** (El Paso Corporation): acquired by Kinder Morgan and delisted in May 2012. yfinance returns price data for EP from 2018 onwards — this belongs to a completely different company that was assigned the same ticker years later. The +73% to +127% single-day moves in 2018 are from this unrelated entity, not the original S&P 500 constituent.
#
# - **CPWR**: delisted and ticker subsequently reassigned to a penny stock or shell company. The -87% / +183% swings within three days in November 2017 are characteristic of a low-float stock with no relation to the original constituent.
#
# No other tickers breach the ±50% threshold. Both corrupted tickers are removed from the dataset.

# %% [markdown]
# ## 6. Cross-Reference and Panel Construction
#
# All datasets are merged into a single long-format panel where each row represents
# one ticker × date observation. Key challenges addressed:
# - **Frequency mismatch**: FRED is monthly, all others daily → forward-filled to daily
# - **Granularity mismatch**: VIX, Fama-French, FRED are market-wide; prices and momentum are ticker-specific
# - **CPI transformation**: year-on-year percentage change to ensure stationarity

# %% [markdown]
# ### FRED Publication Lag — Point-in-Time Correction
#
# FRED dates monthly observations at the **start of the reference period**: the January 2025 value carries index `2025-01-01`. In reality the data is published days later:
#
# | Series | Typical release | Shift applied |
# |---|---|---|
# | `FEDFUNDS` | ~5 business days after month end | +5 days |
# | `UNRATE` | First Friday of following month (~7 days) | +7 days |
# | `CPIAUCSL` | ~13 days after month end | +13 days |
#
# Each series is shifted independently by its actual publication lag before resampling to daily frequency. This avoids look-ahead bias while minimising the unnecessary data loss of a blanket one-month shift.

# %%
# ── CPI Year-on-Year transformation ──────────────────────────────────
fred['CPI_YoY'] = fred['CPIAUCSL'].pct_change(12) * 100
fred = fred.drop(columns=['CPIAUCSL'])

# ── Point-in-time correction: series-specific publication lags ────────
# FEDFUNDS: H.15 release ~5 days after month end
# UNRATE:   Employment Situation, first Friday of following month (~7 days)
# CPI_YoY:  CPI released ~13 days after month end
fred_pit = pd.DataFrame({
    'FEDFUNDS': pd.Series(fred['FEDFUNDS'].values, index=fred.index + pd.DateOffset(days=5)),
    'UNRATE':   pd.Series(fred['UNRATE'].values,   index=fred.index + pd.DateOffset(days=7)),
    'CPI_YoY':  pd.Series(fred['CPI_YoY'].values,  index=fred.index + pd.DateOffset(days=13)),
})

# ── Forward fill FRED from monthly to daily ───────────────────────────
fred_daily = fred_pit.resample('D').ffill()
fred_daily = fred_daily.reindex(prices_clean.index, method='ffill')

# ── Align all datasets to prices index ───────────────────────────────
vix_aligned      = vix.reindex(prices_clean.index, method='ffill')
ff_aligned       = ff.reindex(prices_clean.index, method='ffill')
fred_aligned     = fred_daily.reindex(prices_clean.index)
momentum_aligned = momentum.reindex(prices_clean.index)

# ── Compute forward simple returns ─────────────────────────────
forward_returns = prices_clean.pct_change(21).shift(-21)

print(f"All datasets aligned to {len(prices_clean.index)} trading days")
print(f"Date range: {prices_clean.index[0].date()} to {prices_clean.index[-1].date()}")

# ── Build long-format panel ───────────────────────────────────────────
panels = []

for ticker in prices_clean.columns:
    df = pd.DataFrame({
        'date'           : prices_clean.index,
        'ticker'         : ticker,
        'forward_return' : forward_returns[ticker].values,
        'momentum'       : momentum_aligned[ticker].values,
        'VIX'            : vix_aligned.values.flatten(),
        'Mkt_RF'         : ff_aligned['Mkt-RF'].values,
        'SMB'            : ff_aligned['SMB'].values,
        'HML'            : ff_aligned['HML'].values,
        'FEDFUNDS'       : fred_aligned['FEDFUNDS'].values,
        'CPI_YoY'        : fred_aligned['CPI_YoY'].values,
        'UNRATE'         : fred_aligned['UNRATE'].values,
    })
    panels.append(df)

panel = pd.concat(panels, ignore_index=True)

print(f"\nPanel shape: {panel.shape}")
print(f"Missing values:\n{panel.isnull().sum()}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/alpha-research/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'CPIAUCSL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 2
#       1 # ── CPI Year-on-Year transformation ──────────────────────────────────
# ----> 2 fred['CPI_YoY'] = fred['CPIAUCSL'].pct_change(12) * 100
#       3 fred = fred.drop(columns=['CPIAUCSL'])
#       4
#       5 # ── Point-in-time correction: series-specific publication lags ────────
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/alpha-research/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/alpha-research/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'CPIAUCSL'

# %%
panel
# Out:
#               date ticker  forward_return  momentum        VIX  Mkt_RF   SMB  \
# 0       2010-01-04      A       -0.056230       NaN  20.040001    1.69  0.61
# 1       2010-01-05      A       -0.061047       NaN  19.350000    0.31 -0.64
# 2       2010-01-06      A       -0.054457       NaN  19.160000    0.13 -0.23
# 3       2010-01-07      A       -0.052256       NaN  19.059999    0.40  0.09
# 4       2010-01-08      A       -0.045130       NaN  18.129999    0.33  0.36
# ...            ...    ...             ...       ...        ...     ...   ...
# 1391541 2026-05-11   ZION             NaN  0.402886  18.379999    1.13  0.98
# 1391542 2026-05-12   ZION             NaN  0.329672  17.990000    1.13  0.98
# 1391543 2026-05-13   ZION             NaN  0.406225  17.870001    1.13  0.98
# 1391544 2026-05-14   ZION             NaN  0.419944  17.260000    1.13  0.98
# 1391545 2026-05-15   ZION             NaN  0.393717  18.430000    1.13  0.98
#
#           HML  FEDFUNDS  CPI_YoY  UNRATE
# 0        1.14       NaN      NaN     NaN
# 1        1.22       NaN      NaN     NaN
# 2        0.55       NaN      NaN     NaN
# 3        0.96       NaN      NaN     NaN
# 4        0.02       NaN      NaN     NaN
# ...       ...       ...      ...     ...
# 1391541 -0.71       NaN      NaN     NaN
# 1391542 -0.71       NaN      NaN     NaN
# 1391543 -0.71       NaN      NaN     NaN
# 1391544 -0.71       NaN      NaN     NaN
# 1391545 -0.71       NaN      NaN     NaN
#
# [1391546 rows x 11 columns]

# %%
# ── Drop NaN rows ─────────────────────────────────────────────────────
panel_clean = panel.dropna(subset=['forward_return', 'momentum'])

print(f"Panel before dropna: {panel.shape}")
print(f"Panel after dropna:  {panel_clean.shape}")
print(f"Rows dropped:        {len(panel) - len(panel_clean)}")
print(f"\nMissing values after dropna:")
print(panel_clean.isnull().sum())

# ── Save panel ────────────────────────────────────────────────────────
panel_clean.to_csv('data/panel_clean.csv', index=False)
print(f"\nPanel saved to data/panel_clean.csv")
# Out:
# Panel before dropna: (1366844, 11)
# Panel after dropna:  (1257797, 11)
# Rows dropped:        109047
#
# Missing values after dropna:
# date              0
# ticker            0
# forward_return    0
# momentum          0
# VIX               0
# Mkt_RF            0
# SMB               0
# HML               0
# FEDFUNDS          0
# CPI_YoY           0
# UNRATE            0
# dtype: int64
#
# Panel saved to data/panel_clean.csv

# %% [markdown]
# ### Panel Construction
#
# The final panel contains **1,269,487 observations** across 335 tickers and 4,117 trading days.
# Rows with NaN in `forward_return` (last 21 days per ticker) and `momentum` (first 252 days
# per ticker) are dropped by construction — these observations cannot be used in the regression.

# %% [markdown]
# ## 7. Data Transformations
#
# Before running OLS, the following transformations are applied to address violations
# of classical assumptions:
#
# - **Forward return** → winsorized at 1st and 99th percentile (fat tails)
# - **Momentum** → winsorized at 1st and 99th percentile (fat tails)
# - **All features** → standardized (z-score) for comparability of coefficients
# - **Forward return** → log-return for symmetry and stationarity

# %%
from scipy.stats import mstats
# ── Step 1: Convert forward return to log-return ──────────────────────
# Log-returns are more symmetric and stationary than simple returns
panel_clean = panel_clean.copy()
panel_clean['forward_return'] = np.log(1 + panel_clean['forward_return'])

# ── Step 2: Winsorize forward return and momentum ─────────────────────
# Cap extreme values at 1st and 99th percentile to reduce outlier influence
for col in ['forward_return', 'momentum']:
    panel_clean[col] = mstats.winsorize(panel_clean[col], limits=[0.01, 0.01])

print("Winsorization applied to forward_return and momentum")
print(f"forward_return range: {panel_clean['forward_return'].min():.4f} to {panel_clean['forward_return'].max():.4f}")
print(f"momentum range:       {panel_clean['momentum'].min():.4f} to {panel_clean['momentum'].max():.4f}")

# ── Step 3: Standardize all features ─────────────────────────────────
# Z-score normalization for comparability of OLS coefficients
features = ['momentum', 'VIX', 'Mkt_RF', 'SMB', 'HML', 'FEDFUNDS', 'CPI_YoY', 'UNRATE']

for col in features:
    mean = panel_clean[col].mean()
    std  = panel_clean[col].std()
    panel_clean[col] = (panel_clean[col] - mean) / std

print("\nStandardization applied to all features")
print(panel_clean[features].describe().round(4))
# Out:
# Winsorization applied to forward_return and momentum
# forward_return range: -0.2673 to 0.2384
# momentum range:       -0.7868 to 0.8381
#
# Standardization applied to all features
#            momentum           VIX        Mkt_RF           SMB           HML  \
# count  1.257797e+06  1.257797e+06  1.257797e+06  1.257797e+06  1.257797e+06
# mean   0.000000e+00 -0.000000e+00 -0.000000e+00  0.000000e+00 -0.000000e+00
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.291400e+00 -1.317200e+00 -1.079190e+01 -5.676800e+00 -6.349500e+00
# 25%   -5.212000e-01 -6.648000e-01 -4.037000e-01 -6.029000e-01 -4.890000e-01
# 50%    6.090000e-02 -2.644000e-01  1.690000e-02 -6.900000e-03 -3.430000e-02
# 75%    5.855000e-01  3.647000e-01  4.822000e-01  5.730000e-01  4.709000e-01
# max    2.742500e+00  9.393300e+00  8.588700e+00  8.787900e+00  8.504000e+00
#
#            FEDFUNDS       CPI_YoY        UNRATE
# count  1.257797e+06  1.257797e+06  1.257797e+06
# mean   0.000000e+00 -0.000000e+00  0.000000e+00
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -8.016000e-01 -1.498100e+00 -1.012500e+00
# 25%   -7.799000e-01 -5.739000e-01 -7.624000e-01
# 50%   -6.170000e-01 -2.478000e-01 -4.122000e-01
# 75%    4.741000e-01  2.170000e-01  6.383000e-01
# max    2.064700e+00  3.287300e+00  4.690500e+00

# %% [markdown]
# ## 8. OLS Regression

# %%
import statsmodels.api as sm

# ── Prepare X and y ───────────────────────────────────────────────────
features = ['momentum', 'VIX', 'Mkt_RF', 'SMB', 'HML', 'FEDFUNDS', 'CPI_YoY', 'UNRATE']

X = panel_clean[features]
y = panel_clean['forward_return']

# Add constant for intercept
X = sm.add_constant(X)

# ── Run OLS ───────────────────────────────────────────────────────────
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         forward_return   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     3884.
# Date:                Wed, 03 Jun 2026   Prob (F-statistic):               0.00
# Time:                        11:58:27   Log-Likelihood:             1.3789e+06
# No. Observations:             1257797   AIC:                        -2.758e+06
# Df Residuals:                 1257788   BIC:                        -2.758e+06
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0082   7.21e-05    113.871      0.000       0.008       0.008
# momentum       0.0008   7.33e-05     10.564      0.000       0.001       0.001
# VIX            0.0121   8.04e-05    150.015      0.000       0.012       0.012
# Mkt_RF         0.0005   7.62e-05      6.529      0.000       0.000       0.001
# SMB            0.0006   7.49e-05      8.528      0.000       0.000       0.001
# HML            0.0001   7.23e-05      2.058      0.040    7.08e-06       0.000
# FEDFUNDS       0.0033    8.9e-05     36.702      0.000       0.003       0.003
# CPI_YoY       -0.0079   8.22e-05    -95.865      0.000      -0.008      -0.008
# UNRATE         0.0020   9.43e-05     20.789      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                    79212.222   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165375.367
# Skew:                          -0.433   Prob(JB):                         0.00
# Kurtosis:                       4.551   Cond. No.                         2.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### OLS Results — First Attempt
#
# The pooled OLS regression on the full daily panel yields an R² of **2.4%**, which is
# realistic for financial return prediction. All coefficients are statistically significant,
# however their economic magnitude is negligible — a direct consequence of having 1.2 million
# observations where even trivial effects become significant.
#
# Two diagnostic tests reveal serious violations of OLS assumptions:
#
# - **Durbin-Watson = 0.115**: indicates near-perfect positive serial autocorrelation in
#   residuals. The root cause is the **overlapping returns problem** — consecutive
#   forward returns share 20 out of 21 days, making them almost identical by construction.
#   This renders standard errors unreliable and inflates t-statistics artificially.
#
# - **Jarque-Bera test (p = 0.000)**: residuals are non-normal, with excess kurtosis of
#   4.56 — fat tails remain despite winsorization.
#
# The β estimates are still unbiased, but standard errors and p-values cannot be trusted.

# %% [markdown]
# ### Correction Strategy
#
# To address the overlapping returns problem, we resample the panel to **one observation
# per ticker every 21 trading days** — matching the horizon of the forward return.
# This ensures consecutive observations are non-overlapping and approximately independent,
# bringing the Durbin-Watson statistic closer to 2 and making standard errors reliable.
#
# The sample size drops from 1.27 million to approximately 60,000 observations — a real
# reduction, but the remaining observations are statistically independent and therefore
# genuinely informative.

# %%
# ── Resample panel to non-overlapping observations ────────────────────
# Take one observation per ticker every 21 trading days
# This eliminates the overlapping returns problem

panel_monthly = (
    panel_clean
    .groupby('ticker', group_keys=False)
    .apply(lambda x: x.iloc[::21])
    .reset_index(drop=True)
)

print(f"Panel daily shape:   {panel_clean.shape}")
print(f"Panel monthly shape: {panel_monthly.shape}")
print(f"Observations lost:   {len(panel_clean) - len(panel_monthly)}")

# ── Run OLS on non-overlapping panel ─────────────────────────────────
X_m = sm.add_constant(panel_monthly[features])
y_m = panel_monthly['forward_return']

model_monthly = sm.OLS(y_m, X_m).fit()
print(model_monthly.summary())
# Out:
# Panel daily shape:   (1257797, 11)
# Panel monthly shape: (60206, 10)
# Observations lost:   1197591
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         forward_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     169.3
# Date:                Wed, 03 Jun 2026   Prob (F-statistic):          8.21e-284
# Time:                        11:58:27   Log-Likelihood:                 66318.
# No. Observations:               60206   AIC:                        -1.326e+05
# Df Residuals:                   60197   BIC:                        -1.325e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0087      0.000     26.115      0.000       0.008       0.009
# momentum       0.0017      0.000      4.997      0.000       0.001       0.002
# VIX            0.0105      0.000     26.433      0.000       0.010       0.011
# Mkt_RF        -0.0030      0.000     -8.001      0.000      -0.004      -0.002
# SMB            0.0063      0.000     17.617      0.000       0.006       0.007
# HML            0.0024      0.000      7.327      0.000       0.002       0.003
# FEDFUNDS       0.0038      0.000      9.223      0.000       0.003       0.005
# CPI_YoY       -0.0069      0.000    -18.094      0.000      -0.008      -0.006
# UNRATE         0.0020      0.000      4.549      0.000       0.001       0.003
# ==============================================================================
# Omnibus:                     3447.589   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7008.760
# Skew:                          -0.405   Prob(JB):                         0.00
# Kurtosis:                       4.462   Cond. No.                         2.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### OLS Results — Corrected Model
#
# After resampling to non-overlapping 21-day observations, the Durbin-Watson statistic
# improves dramatically from **0.115 to 2.075** — indicating no meaningful serial
# autocorrelation. The R² remains stable at **2.3%**, confirming the signal was genuine
# and not an artefact of overlapping returns.
#
# Key changes in coefficients:
# - **Mkt_RF** flips sign from positive to negative — the daily panel coefficient was
#   distorted by autocorrelation
# - **SMB** and **HML** increase substantially — their effect was previously underestimated
# - **CPI_YoY** remains the strongest negative predictor — robust across both models
#
# Non-normality of residuals persists (Kurtosis = 4.45) — an inherent feature of
# financial return distributions that cannot be fully eliminated through winsorization alone.

# %%
panel_monthly.to_csv('data/panel_monthly.csv', index=False)
print("Panel monthly saved")
# Out:
# Panel monthly saved

# %% [markdown]
# ## 10. Final Considerations
#
# - **Survivorship bias**: 130 tickers (26% of the universe) could not be downloaded
#   from yfinance, reintroducing survivorship bias. A commercial database such as
#   CRSP would eliminate this issue.
#
# - **Sample period**: 2010-2026 includes highly anomalous regimes (COVID-19,
#   aggressive Fed tightening) that may not be representative of future market conditions.
#
# - **Non-normal residuals**: despite winsorization, residuals retain excess kurtosis.
#   A rank-based transformation or robust regression would be more appropriate.
#
# - **Standard errors**: clustered standard errors by ticker would further improve
#   inference by accounting for cross-sectional correlation.
#
# - **Model complexity**: a pooled OLS is a first attempt. Fixed effects,
#   Fama-MacBeth, or machine learning models would likely improve predictive power.
